# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas
train_path ="C:\\Users\\Kshore N\\Documents\\PythonProject2\\TITATNIC-SURVIVAL-PREDICTIONS\\data\\raw\\train (1).csv"
train_df=pd.read_csv(train_path)
sns.countplot(x='Sex',hue='Survived',data=train_df)
plt.title("SURVIVAL BY GENDER")
plt.savefig('C:\\Users\\Kshore N\\Documents\\PythonProject2\\TITATNIC-SURVIVAL-PREDICTIONS\\notebooks\\plots\\survival_by_gender.png')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

train_path ="C:\\Users\\Kshore N\\Documents\\PythonProject2\\TITATNIC-SURVIVAL-PREDICTIONS\\data\\raw\\train (1).csv"
train_df=pd.read_csv(train_path)
sns.barplot(data=train_df,x='Survived',hue='Sex',y='Age')
plt.title(' BASED ONTHE AGE OF SURVIVAL BY GENDER ')

plt.savefig('C:\\Users\\Kshore N\\Documents\\PythonProject2\\TITATNIC-SURVIVAL-PREDICTIONS\\notebooks\\plots\\age_survival.png')
plt.show()
